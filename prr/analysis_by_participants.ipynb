# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
datafile = 'cyclesix_owl_emotions.csv'
df = pd.read_csv(datafile)

# %%
participants = df['video_id'].unique()

# %%
#for ii, pid in enumerate(participants):

# %%
sorted = df.groupby(by='video_id', sort=False).size().reset_index(name='counts')

# %%
sorted.sort_values(by='counts', inplace=True)

# %%
sns.barplot(data=sorted, y='counts', x='video_id')
# Out:
# <Axes: xlabel='video_id', ylabel='counts'>
